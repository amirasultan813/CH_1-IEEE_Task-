# %% [markdown]
# # 📘 Ch:1 Questions:
# ________________

# %% [markdown]
# #### 1) Write a General definition for `Artificial Intellegence`:

# %%
# Write your answer here
'''
    is defined as the intelligence of machines that allows them to  learn, and perform intellectual tasks much like humans,solve any kind of complex problem.
    ex: (1.narrow AI , 2.general AI , 3.super AI) .
'''

# %% [markdown]
# _________________________
# #### 2) Write a General definition for `Machine learning`:

# %%
'''
 - It's the field of study that gives computer ability to learn without being explicity programmed.
 - It's science of programming computers , they can learn from data.
 '''

# %% [markdown]
# _________________________
# #### 3) What is the relation between `Artificial Intellegence` and `Machine learning`:

# %%
# - ML is subfield of AI and ML can be used for AI applications.
# - They change over time not static.

# %% [markdown]
# ___________________
# #### 4) Machine learning is a good solution for <font color = 'red'>**(Choose the correct answer)**</font>:
#
# 1. [ ] Problems that either are too complex for traditional approaches or have no known algorithm. (ex: building a program to distinguish between the pronounciation of word "Two" and "One" in different voice records)
#
# 2. [ ] Fluctuating environments (where your training data needs to be up to date) ex: stock market.
#
# 3. [ ] Getting insights about complex problems and large amounts of data
#
# 4. [ ] All of the above.

# %%
# 4- all of the above

# %% [markdown]
# _______________________________________

# %% [markdown]
# #### 5) Different classifications for ML (Machine Learning) systems  <font color = 'red'>**(Fill the gaps)**</font> :
#
#
# > 1. Depending on how they are supervised during training, ML systems are classified into `(.... & .... & .... & .... & ....)`
#
# >2. Depending on whether or not they can learn incrementally on the fly, ML systems are classified into `(.... & ....)`
#
# >3. Depending on whether they work by simply comparing new data points to known data points, or instead by detecting patterns in the training data and building a predictive model, ML systems are classified into `(.... & ....)`
#
# >4. In case of *generalization*, ML systems are classified mainly into `(.... & ....)`
#
# >5. What is meant by *generalization* ?

# %%
# write your answers here:
# 1. Regression and classification.
# 2. batch and online learning.
# 3. instance-based & model-based learning.
# 4. instance based & model based.
# 5. generalization is the ability to perform well on new data & related to overfitting,so if the  model is overfitted then it isn't generalize well.

# %% [markdown]
# __________________________________

# %% [markdown]
# #### 6) `KNN(K-Nearest Neighbour)-based` machine learning systems are classified as  <font color = 'red'>**(Choose the correct answer & explain)**</font> :
# 1. instance-based systems
# 2. model-based systems

# %%
# 1- instance-based systems as  
# .it's requires a measure of similarity between 2 objects.
# .the systems learns the examples by heart , then generalizes to new cases by using similarity of measure to compare them to the learned examples.

# %% [markdown]
# __________________________________

# %% [markdown]
# #### 7) `Linear-Regression-based` machine learning systems are classified as <font color = 'red'>**(Choose the correct answer & explain)**</font> :
# 1. instance-based systems
# 2. model-based systems

# %%
# 2- model-based sysytems :
# .its a way to generalize from a set of examples is to build a model of these examples and then use model to make predictions.

# %% [markdown]
# __________________________________

# %% [markdown]
# #### 8) `Google Photos service` machine learning task is classified as <font color = 'red'>**(choose and explain)**</font>:
#
# 1. `supervised`
#
# 2. `semi-supervised`
#
# 3. `self-supervised`
#
# 4. `unsupervised`
#
# 5. `reinforcement learning`
#
#
#
# > - *hint: **Google Phohots** works like that:*
#
# > When you upload many photos, the system automatically recognizes that the same person **A** appears in photos 1, 5, and 11, while another person **B** appears in photos 2, 5, and 7. **After that** system needs you to tell it who those two persons are. You just add one label per person, and the system is able to name those persons in all other photos, which is useful for searching photos.

# %%
'''
  2- semi-supervised :
    .most of them are combination of supervised and unsupervised :
    .just add one label per person and it is able to name everyone in every photo (supervised),systems need to be told it who these people are.
    .system automatically recognizes people one you upload a photo (unsupervised (clustering)).
    '''

# %% [markdown]
# _________________________

# %% [markdown]
# #### 9) Is `Reinforcement Learning` the only machine learning technique in which the model *doesn't need sample data* to train on ?!
# > *explain your answer briefly*

# %%
'''
  the learning system called agent , in this context:
      1.can obesrve the environment.
      2.select action using policy.
      3. perform actions.
      4. get reward or penalty.
      5. update ploicy.
      6. iterate untill an optimal policy is found.(action the agent should choose).
'''

# %% [markdown]
# _________________________

# %% [markdown]
# #### 10) Machine learning accompained problems are classified into either **`data-related problems`** or **`model-related problems`**.
# <br><font color = "red">**(Mention 3 problems for each category)**</font>

# %%
# write your answers here:
'''
    = data-related problems:
      1.insufficient quantity of data.
      2.non-representative data.
      3.poor quality (errors ,noise:(discard or fix it) ,outliers ).
      4.irrelevant features (feature selection or feature extraction).

    = model-related problems:
      1.overfiting as:(1-complex model , 2-small data).
      2.underfiting as:(1-simple model).
'''

# %% [markdown]
# __________________

# %% [markdown]
# #### 11) What do you know about this equation?
# ![image.png](data:image/png;base64,...)

# %%
# write your answers here:
'''
   in the problem of overfiting ,constraining model to make it simpler and reduce this risk is called regularization.
   this gives algorithm 2 degrees of freedom to adapt model to training data :
   forced theta_0 =0 and it has only 1 degree of freedom and would have harder time to fit data.
   so, in this equation : while cost function reduce error , it will be reduce and restrict on theta.
'''

# %% [markdown]
# _______________________

# %% [markdown]
# #### 12) How can we handle **`overfitting`**? <font color = "red">**(mention 2 ways)** </font>

# %%
# write your answers here:
'''
    1.simplify model:(regularization)by selecting one with fewer parameters.
    2.get more data.
    3.reduce noise in training data.
'''

# %% [markdown]
# _______________________

# %% [markdown]
# #### 13) Increasing the number of data instances help reducing:
#
# 1. Overfitting
#
# 2. Underfitting
#
# 3. Both

# %%
# write your answers here:
'''
      2. overfiting
'''

# %% [markdown]
# _______________________

# %% [markdown]
# #### 14) What is the purpose of a `validation set`?

# %%
# write your answers here:
'''
    is used to fine-tune the hyperparameters of the model and is a part of the training of the model.
    The model only sees this data for evaluation and doesn't learn from this data,unbiased evaluation of the model
'''

# %% [markdown]
# _______________________

# %% [markdown]
# #### 15) What can go wrong if you tune hyperparameters using the test set?

# %%
# write your answers here:
'''
     Data that has already used to tune hyperparameters is reused to estimate performance. This will give a deceptive estimate.
     This isn't overfitting itself but if overfitting is happening , you won't know it.
     test set used for estimating final performance.
'''

# %% [markdown]
# _______________________

# %% [markdown]
# #### 16) What is `cross-validation` and in which case we use it?

# %%
# write your answers here:
'''
    it is a statistical method used to estimate the performance  of ml models.
    It is used to avoid overfitting in a predictive model, particularly in a case where the amount of data may be limited.

'''

# %% [markdown]
# _______________________

# %% [markdown]
# # 📗 Ch:1 Terminologies:
# ________________

# %% [markdown]
# 1) In Supervised tasks, both **`target`** & **`label`** refers to the same thing. However, `(.....)` is commonly used with **Regression tasks** and  `(.....)` with **Classification tasks**.

# %%
# write your answers here:
'''
    - target (regression)
    - label (classification)
'''

# %% [markdown]
# _____________________

# %% [markdown]
# 2) **`Features`** are sometimes called **`predictors`** or **`attributes`**. <font color = 'red'> **(True / False)** </font>

# %%
# write your answers here:
# True

# %% [markdown]
# ________________

# %% [markdown]
# 3) What is the difference between **`model parameters`** & **`hyperparameters`** ? <font color = 'red'> **(write one example example for each)**</font>

# %%
# write your answers here:
'''
    model parameters: estimated based on the data during model training. ex: (theta_0, theta_1).
    hyperparameters: set manually and are used to help in estimating model parameters.
                   it's values is set before the model start training. They cannot be learned by fitting the model to the data.
                   ex: learning rate in gradient descent
'''

# %% [markdown]
# ___________________________

# %% [markdown]
# 4) Both **`utility function (or fitness function)`** and **`cost function`** are measure of performance. <font color = 'red'> **(what is the difference?)**</font>

# %%
# write your answers here:
'''
    - In genetic algorithms, the fitness function is any function that assesses the quality of an solution.
    - utility function is usually negative of an error function, in the sense that it measures a positive aspect.
'''

# %% [markdown]
# ___________________________

# %% [markdown]
# 5) What is meant by (**`model rot or "data drift"`**)?

# %%
# write your answers here:
'''
    if there is changes in the data, we normally call it as Data Drift .
    .changes in the input data.
    .changes in the values of the features used to define or predict a target label.
    .changes in the properties of the independent variable
'''

# %% [markdown]
# __________________

# %% [markdown]
# 6) What is meant by **`generalization error`** (also known as **`out-of-sample error`**) ?

# %%
# write your answers here:
'''
    measure of how accurately an algorithm is able to predict outcome values for test data.
'''

# %% [markdown]
# __________________

# %% [markdown]
# 7) **Overfitting** is also known as `(.....)`
#
# 8) **Underfitting** is also known as `(.....)`
#
# <font color = "red">**(Fill the gaps and explain)**<font>
#
# ![image.png](data:image/png;base64,...)

# %%
# write your answers here:
'''
    7.high variance:
     -learned the training data so well that it cannot generalise well to make predictions on new and unseen data. 
     -These models are not good for predicting new data.
    8.poor performance on both datasets ,has not learned the patterns in the training data well and is unable to generalize well on the new data.
'''

# %% [markdown]
# __________________

# %% [markdown]
# # 📙 Problem Solving:
# ________________

# %% [markdown]
# [Problem 1](https://leetcode.com/problems/remove-all-adjacent-duplicates-in-string/)

# %%
class Solution(object):
    def removeDuplicates(self, s):
        if not s:
            return s
        
        res = [s[0]]
        for i in s[1:]:
            if res and i == res[-1]:
                res.pop()
            else:
                res.append(i)
                
        return "".join(res)

# %% [markdown]
# [Problem 2](https://codeforces.com/group/MWSDmqGsZm/contest/223206/problem/Z)

# %%
# https://codeforces.com/group/MWSDmqGsZm/contest/223206/problem/Z
